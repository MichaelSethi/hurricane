# %%
# %load script
# names of hurricanes
names = ['Cuba I', 'San Felipe II Okeechobee', 'Bahamas', 'Cuba II', 'CubaBrownsville', 'Tampico', 'Labor Day', 'New England', 'Carol', 'Janet', 'Carla', 'Hattie', 'Beulah', 'Camille', 'Edith', 'Anita', 'David', 'Allen', 'Gilbert', 'Hugo', 'Andrew', 'Mitch', 'Isabel', 'Ivan', 'Emily', 'Katrina', 'Rita', 'Wilma', 'Dean', 'Felix', 'Matthew', 'Irma', 'Maria', 'Michael']

# months of hurricanes
months = ['October', 'September', 'September', 'November', 'August', 'September', 'September', 'September', 'September', 'September', 'September', 'October', 'September', 'August', 'September', 'September', 'August', 'August', 'September', 'September', 'August', 'October', 'September', 'September', 'July', 'August', 'September', 'October', 'August', 'September', 'October', 'September', 'September', 'October']

# years of hurricanes
years = [1924, 1928, 1932, 1932, 1933, 1933, 1935, 1938, 1953, 1955, 1961, 1961, 1967, 1969, 1971, 1977, 1979, 1980, 1988, 1989, 1992, 1998, 2003, 2004, 2005, 2005, 2005, 2005, 2007, 2007, 2016, 2017, 2017, 2018]

# maximum sustained winds (mph) of hurricanes
max_sustained_winds = [165, 160, 160, 175, 160, 160, 185, 160, 160, 175, 175, 160, 160, 175, 160, 175, 175, 190, 185, 160, 175, 180, 165, 165, 160, 175, 180, 185, 175, 175, 165, 180, 175, 160]

# areas affected by each hurricane
areas_affected = [['Central America', 'Mexico', 'Cuba', 'Florida', 'The Bahamas'], ['Lesser Antilles', 'The Bahamas', 'United States East Coast', 'Atlantic Canada'], ['The Bahamas', 'Northeastern United States'], ['Lesser Antilles', 'Jamaica', 'Cayman Islands', 'Cuba', 'The Bahamas', 'Bermuda'], ['The Bahamas', 'Cuba', 'Florida', 'Texas', 'Tamaulipas'], ['Jamaica', 'Yucatn Peninsula'], ['The Bahamas', 'Florida', 'Georgia', 'The Carolinas', 'Virginia'], ['Southeastern United States', 'Northeastern United States', 'Southwestern Quebec'], ['Bermuda', 'New England', 'Atlantic Canada'], ['Lesser Antilles', 'Central America'], ['Texas', 'Louisiana', 'Midwestern United States'], ['Central America'], ['The Caribbean', 'Mexico', 'Texas'], ['Cuba', 'United States Gulf Coast'], ['The Caribbean', 'Central America', 'Mexico', 'United States Gulf Coast'], ['Mexico'], ['The Caribbean', 'United States East coast'], ['The Caribbean', 'Yucatn Peninsula', 'Mexico', 'South Texas'], ['Jamaica', 'Venezuela', 'Central America', 'Hispaniola', 'Mexico'], ['The Caribbean', 'United States East Coast'], ['The Bahamas', 'Florida', 'United States Gulf Coast'], ['Central America', 'Yucatn Peninsula', 'South Florida'], ['Greater Antilles', 'Bahamas', 'Eastern United States', 'Ontario'], ['The Caribbean', 'Venezuela', 'United States Gulf Coast'], ['Windward Islands', 'Jamaica', 'Mexico', 'Texas'], ['Bahamas', 'United States Gulf Coast'], ['Cuba', 'United States Gulf Coast'], ['Greater Antilles', 'Central America', 'Florida'], ['The Caribbean', 'Central America'], ['Nicaragua', 'Honduras'], ['Antilles', 'Venezuela', 'Colombia', 'United States East Coast', 'Atlantic Canada'], ['Cape Verde', 'The Caribbean', 'British Virgin Islands', 'U.S. Virgin Islands', 'Cuba', 'Florida'], ['Lesser Antilles', 'Virgin Islands', 'Puerto Rico', 'Dominican Republic', 'Turks and Caicos Islands'], ['Central America', 'United States Gulf Coast (especially Florida Panhandle)']]

# damages (USD($)) of hurricanes
damages = ['Damages not recorded', '100M', 'Damages not recorded', '40M', '27.9M', '5M', 'Damages not recorded', '306M', '2M', '65.8M', '326M', '60.3M', '208M', '1.42B', '25.4M', 'Damages not recorded', '1.54B', '1.24B', '7.1B', '10B', '26.5B', '6.2B', '5.37B', '23.3B', '1.01B', '125B', '12B', '29.4B', '1.76B', '720M', '15.1B', '64.8B', '91.6B', '25.1B']

# deaths for each hurricane
deaths = [90,4000,16,3103,179,184,408,682,5,1023,43,319,688,259,37,11,2068,269,318,107,65,19325,51,124,17,1836,125,87,45,133,603,138,3057,74]

# write your update damages function here:
# print(damages)

def damages_updated_data(damages):
    conversion = {"M": 10**6,"B":10**9}
    damages_updated = []
    
    for i in damages:
        if i == "Damages not recorded":
            damages_updated.append(i)
        if i[-1] == 'M':
            damages_updated.append(float(i.strip('M'))*conversion["M"])
        if i[-1] == 'B':
            damages_updated.append(float(i.strip('B'))*conversion["B"])
    return damages_updated

damages_updated = damages_updated_data(damages)
# print(damages_updated)
damages = damages_updated
    

# write your construct hurricane dictionary function here:

def hurricane():
    hurricanes = {}
    for i in range(len(names)):
        hurricanes[names[i]] = {"Name": names[i], "Month": months[i],"Year": years[i], 
                                "Max Sustained Wind": max_sustained_winds[i],"Areas Affected": areas_affected[i], 
                                "Damage": damages[i], "Deaths": deaths[i]}   
    return hurricanes

hurricanes = hurricane()
#print(hurricanes)

# write your construct hurricane by year dictionary function here:

def hurricane_year():
    HurricanesbyYear = {}
    for year in years:
        HurricanesbyYear[year] = [hurricane for hurricane in hurricanes.values() if hurricane["Year"] == year]
    return HurricanesbyYear
# print(hurricane_year())   





# write your count affected areas function here:
#Option 1
from collections import Counter
from itertools import chain

Affected_areas_counted = Counter(chain.from_iterable(areas_affected))


#Option 2
def count_affected_areas():
    count={}
    for hurricane in hurricanes.values():
        for area in hurricane["Areas Affected"]:
            if area in count.keys():
                count[area] +=1
            else:
                count[area] = 1
    return count

areas_affected_count = count_affected_areas()
#print(areas_affected_count)

# #write your find most affected area function here:

# area, hits = most_affected_area(areas_affected_count)

# def most_affected_area(areas):
#     max_area = ""
#     max_hits = 0
#     for area,hits in areas.items():
#         if hits > max_hits:
#             max_area = area
#             max_hits = hits
#     return max_area, max_hits
# #print("Most affected area is: {area} with {hits} hits".format(area = area, hits = hits))


# write your greatest number of deaths function here:

deadliest_hurricanes = {key: value for key, value in zip(names, deaths)}
#print(deadliest_hurricanes)


def greatest_number_of_deaths(biggestnumberofdeaths):
    deadliest_hurricane = ""
    max_deaths = 0
    for hurricane, death in biggestnumberofdeaths.items():
        if death > max_deaths:
            deadliest_hurricane = hurricane
            max_deaths = death
    return deadliest_hurricane, max_deaths 

hurricane, death = greatest_number_of_deaths(deadliest_hurricanes)
#print("Deadliest Hurricane is: {hurricane} with {death} deaths".format(hurricane = hurricane, death = death))
    

# write your catgeorize by mortality function here:

def mortality_categorization(hurricane_dictionary):
    hurricane_by_mortality = {0:[], 1:[], 2:[], 3:[], 4:[], 5:[]}
    for hurricane in hurricanes.values():
        deaths = hurricane.get("Deaths")
        if deaths == 0:
            hurricane_by_mortality[0].append(hurricane.get("Name"))
        elif deaths > 0 and deaths <= 100:
            hurricane_by_mortality[1].append(hurricane.get("Name"))
        elif deaths > 100 and deaths <= 500:
            hurricane_by_mortality[2].append(hurricane.get("Name"))
        elif deaths > 500 and deaths <= 1000:
            hurricane_by_mortality[3].append(hurricane.get("Name"))        
        elif deaths > 1000 and deaths <= 10000:
            hurricane_by_mortality[4].append(hurricane.get("Name"))
        elif deaths > 10000:
            hurricane_by_mortality[5].append(hurricane.get("Name"))
    return hurricane_by_mortality

mortality_rating_dictionary = mortality_categorization(hurricanes)
#print(mortality_rating_dictionary)

# write your greatest damage function here:

most_damage = {key: value for key, value in zip(names, damages)}
#print(most_damage)


def greatest_damage(biggestdamage):
    max_damage_can = ""
    max_damage = 0
    for hurricane, damage in biggestdamage.items():
        if isinstance(damage, float) is True:
            if damage > max_damage:
                max_damage_cane = hurricane
                max_damage = damage

    return max_damage_cane, max_damage 

hurricane, damage = greatest_damage(most_damage)

most_damaging_hurricane = greatest_damage(most_damage)
#print(most_damaging_hurricane)

# write your catgeorize by damage function here:

def damage_categorization(hurricane_damages):
    hurricane_by_damage = {0:[], 1:[], 2:[], 3:[], 4:[], 5:[]}
    for hurricane in hurricanes.values():
        damage = hurricane.get("Damage")
        if isinstance(damage, float) is True:
            if damage == float(0):
                hurricane_by_damage[0].append(hurricane.get("Name"))
            elif damage > float(0) and damage <= float(10**8):
                hurricane_by_damage[1].append(hurricane.get("Name"))
            elif damage > float(10**8) and damage <= float(10**9):
                hurricane_by_damage[2].append(hurricane.get("Name"))
            elif damage > float(10**9) and damage <= float(10**10):
                hurricane_by_damage[3].append(hurricane.get("Name"))        
            elif damage > (10**10) and damage <= float(10**11):
                hurricane_by_damage[4].append(hurricane.get("Name"))
            elif damage > float(10**11):
                hurricane_by_damage[5].append(hurricane.get("Name"))
    return hurricane_by_damage

damage_rating_dictionary = damage_categorization(hurricanes)
#print(damage_rating_dictionary)
# Out:
# {0: [], 1: ['San Felipe II Okeechobee', 'Cuba II', 'CubaBrownsville', 'Tampico', 'Carol', 'Janet', 'Hattie', 'Edith'], 2: ['New England', 'Carla', 'Beulah', 'Felix'], 3: ['Camille', 'David', 'Allen', 'Gilbert', 'Hugo', 'Mitch', 'Isabel', 'Emily', 'Dean'], 4: ['Andrew', 'Ivan', 'Rita', 'Wilma', 'Matthew', 'Irma', 'Maria', 'Michael'], 5: ['Katrina']}
